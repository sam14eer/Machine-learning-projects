# %%
# importing required liabraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
# importing dataset and creating the dataframe
wine_data=pd.read_csv('winequality-red.csv')

# %%
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine_data.shape
# Out:
# (1599, 12)

# %%
#checking for missing values in dataset
wine_data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# checking basic information of the data like columns,datatypes,null values and data size
wine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wine_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# checking and visualizing the corelations of the fileds with target data
correlation=wine_data.corr()
plt.figure(figsize=(5,5))
sns.heatmap(correlation,annot=True,fmt='.1f',cbar=True,square=True,color='blue',annot_kws={'size':8})
plt.title('Corelation matrics of wine data')
plt.show()

# %%
# getting the wine qualitywise data
wine_data['quality'].value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
# wine quality graph vs counts
plt.figure(figsize=(4,8))
sns.catplot(x='quality',data=wine_data,kind='count')
plt.title('Wine quality wise count')
plt.show()

# %%
# wine quality vs volatile acidity graph
plt.figure(figsize=(7,4))
sns.barplot(x='quality',y='volatile acidity',data=wine_data,palette=['red','green','yellow','pink','orange','Purple'])
plt.title('wine quality vs volatile acidity graph')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7864\3054371074.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='quality',y='volatile acidity',data=wine_data,palette=['red','green','yellow','pink','orange','Purple'])

# %%
plt.figure(figsize=(7,4))
sns.barplot(x='quality',y='alcohol',data=wine_data,palette=['red','green','yellow','pink','orange','Purple'])
plt.title('quality vs alcohol graph')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_7864\1572780717.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='quality',y='alcohol',data=wine_data,palette=['red','green','yellow','pink','orange','Purple'])

# %%
# separating the data in fileds and target
x=wine_data.drop(columns=('quality'))
y=wine_data['quality']

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# converting the quality filed into only two category i.e binary classification
y=wine_data['quality'].apply(lambda y_value:1 if y_value>=7 else 0)

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: quality, Length: 1599, dtype: int64

# %%
#train test splitting the dataset
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=3)

# %% [markdown]
# ## Random forest classification model

# %%
# initializing the random forest model
wine_model=RandomForestClassifier()

# %%
wine_model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
# testing data accuracy using random forest classifier

test_prediction=wine_model.predict(X_test)
test_accu=accuracy_score(training_prediction,Y_test)
print('accuracy of the model is =',training_accu)
# Out:
# accuracy of the model is = 0.934375

# %% [markdown]
# ## Logestic regression model

# %%
log_model=LogisticRegression()

# %%
log_model.fit(X_train,Y_train)
# Out:
# C:\Newfolder\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# accuracy of logestic regression on testing data

test_pred=log_model.predict(X_test)
log_test_accu=accuracy_score(test_pred,Y_test)
log_test_accu
# Out:
# 0.896875

# %%
# accuracy of logestic regression on training data

train_pred=log_model.predict(X_train)
log_train_accu=accuracy_score(train_pred,Y_train)
log_train_accu
# Out:
# 0.8749022673964034
